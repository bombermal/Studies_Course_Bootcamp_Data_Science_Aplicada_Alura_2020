# %% [markdown]
# <a href="https://colab.research.google.com/github/bombermal/Bootcamp_Data_Science_Aplicada_Alura_2020/blob/main/M01_02_Primeiras_visualiza%C3%A7%C3%B5es_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Imports

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as tck

# %%
#data
url = "https://github.com/alura-cursos/agendamento-hospitalar/raw/main/dados/A160324189_28_143_208.csv"
dataRaw = pd.read_csv(url, encoding="latin-1", sep=";", skiprows=3, skipfooter = 12, thousands=".", decimal=",",engine='python')

#Options
pd.options.display.float_format="{:.2f}".format

dataRaw
# Out:
#       Unidade da Federação  1992/Mar  ...      2020/Ago          Total
# 0              11 Rondônia         -  ...    3556381.57   929129659.72
# 1                  12 Acre         -  ...             -   420668039.63
# 2              13 Amazonas         -  ...    4726485.73  1771654871.23
# 3               14 Roraima         -  ...    1524478.04   305010883.18
# 4                  15 Pará         -  ...   11559714.54  4437115730.71
# 5                 16 Amapá         -  ...     834187.31   291637984.75
# 6             17 Tocantins         -  ...    2453362.74   999998621.85
# 7              21 Maranhão         -  ...   10916718.78  3632860959.84
# 8                 22 Piauí         -  ...    7926321.69  2130616492.35
# 9                 23 Ceará         -  ...   14559529.59  6197357245.98
# 10  24 Rio Grande do Norte         -  ...    8080160.97  2477372149.60
# 11              25 Paraíba         -  ...    8585226.08  2470550104.25
# ...

# %%
#Subistituindo '-' por 0 e convertendo coluna de string para float
data = dataRaw.set_index("Unidade da Federação")
data = data.replace(to_replace="-", value=0).astype(float)
data
# Out:
#                         1992/Mar  1992/Abr  ...     2020/Ago          Total
# Unidade da Federação                        ...
# 11 Rondônia                 0.00      0.00  ...   3556381.57   929129659.72
# 12 Acre                     0.00      0.00  ...         0.00   420668039.63
# 13 Amazonas                 0.00      0.00  ...   4726485.73  1771654871.23
# 14 Roraima                  0.00      0.00  ...   1524478.04   305010883.18
# 15 Pará                     0.00      0.00  ...  11559714.54  4437115730.71
# 16 Amapá                    0.00      0.00  ...    834187.31   291637984.75
# 17 Tocantins                0.00      0.00  ...   2453362.74   999998621.85
# 21 Maranhão                 0.00      0.00  ...  10916718.78  3632860959.84
# 22 Piauí                    0.00      0.00  ...   7926321.69  2130616492.35
# 23 Ceará                    0.00      0.00  ...  14559529.59  6197357245.98
# 24 Rio Grande do Norte      0.00      0.00  ...   8080160.97  2477372149.60
# ...

# %%
#Seleciono todas as colunas exceto 'Total'
cols = data.columns.tolist()[:-1]

#gráfico
data[cols].T.plot(kind="line", figsize=(15,5))
plt.show()

# %% [markdown]
# Desafio 01: Reposicionar a legenda do gráfico em uma posição mais adequada
#
# Desafio 02: Plotar o gráfico de linha com apenas 5 estados de sua preferência

# %%
#Sample de gráficos
data.loc[:,"2008/Fev":"2020/Ago"].sample(5).T.plot(kind="line", figsize=(15,5))
plt.legend(bbox_to_anchor=(1.18,1), loc="upper right")
plt.show()
